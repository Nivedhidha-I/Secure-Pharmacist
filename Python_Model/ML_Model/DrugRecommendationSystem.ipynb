# %% [markdown]
# # Drug Recommendation System

# %% [markdown]
# ## Steps Taken For Project:
# 1. Imported all the libraries required.
# 2. Importing the datasets
# 3. Did required cleaning of datasets
# 4. Performed munging process (Data which having rating more than 7 was filtered)
# 5. ML models - Naive Bayes Model, Random Forest Model and SVC model (to check which was better fitting)
# 6. Ensembling model by HardVoting (All three accuracies were great, hence to get a combined result)
# 7. Recommending The Medicines based on condition

# %% [markdown]
# ## Preparation Work

# %% [markdown]
# ### Importing Required Libraries

# %%
# munging dataset
import numpy as np
import pandas as pd

# preparing for ml
from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import train_test_split

# making the model
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC

# checking accuracy
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score

# for ensembling the models
from sklearn.ensemble import VotingClassifier

# %% [markdown]
# ### Preparing Dataset

# %%
D = pd.read_csv('/workspaces/Secure-Pharmacist/Python_Model/Datasets/drugsComTrain_raw.csv')
D = pd.concat([D, pd.read_csv('/workspaces/Secure-Pharmacist/Python_Model/Datasets/drugsComTest_raw.csv')], axis=0)
D = D.drop(['uniqueID', 'review', 'date', 'usefulCount'], axis=1)
D.head()
# Out:
#          drugName                   condition  rating
# 0      Omeprazole  Zollinger-Ellison Syndrome      10
# 1          Mirena               Birth Control      10
# 2  Levonorgestrel               Birth Control      10
# 3          Zoloft                  Depression       9
# 4     Phentermine                 Weight Loss      10

# %% [markdown]
# ### Cleaning The Dataset

# %%
D.isna().sum()
D = D.dropna()

# %%
# print("Before removing unwanted data:")
print("Unique Drugs:",len(D.drugName.unique()))
print("Unique Conditions:",len(D.condition.unique()))

D = D[~D.condition.str.contains("span", na=False)]

print("After removing unwanted data:")
print("Unique Drugs:",len(D.drugName.unique()))
print("Unique Conditions:",len(D.condition.unique()))

D.condition.unique()
# Out:
# Unique Drugs: 3646
# Unique Conditions: 855
# After removing unwanted data:
# Unique Drugs: 3646
# Unique Conditions: 855
# array(['Zollinger-Ellison Syndrome', 'Birth Control', 'Depression',
#        'Weight Loss', 'Anxiety and Stress', 'Anxiety',
#        'emale Infertility', 'Pain', 'Obesity', 'Osteoporosis',
#        'Panic Disorde', 'Urinary Tract Infection',
#        'Polycystic Ovary Syndrome', 'Muscle Spasm', 'Opiate Withdrawal',
#        'Hypogonadism Male', 'Ovulation Induction', 'Hashimotos disease',
#        'Bipolar Disorde', 'Opiate Dependence', 'Insomnia',
#        'Underactive Thyroid', 'Breast Cance', 'High Blood Pressure',
#        'ADHD', 'Benign Prostatic Hyperplasia', 'Alopecia',
#        'Erectile Dysfunction', 'Generalized Anxiety Disorde',
#        'Atrophic Vaginitis', 'Sexual Dysfunction SSRI Induced',
#        'Obsessive Compulsive Disorde', 'High Cholesterol',
#        'Hypothyroidism After Thyroid Removal',
#        'Abnormal Uterine Bleeding', 'Renal Cell Carcinoma',
#        'Non-Small Cell Lung Cance', 'ibromyalgia',
#        'Photoaging of the Skin', 'Atrial Fibrillation',
#        'Alzheimers Disease', 'Social Anxiety Disorde',
#        'Breast Cancer Metastatic', 'Rheumatoid Arthritis', 'Sedation',
#        'Constipation', 'Alcohol Dependence', 'Inflammatory Conditions',
#        'Osteoarthritis',
#        'Prevention of Thromboembolism in Atrial Fibrillation', 'Scabies',
#        'mance Anxiety', 'Sinusitis', 'Skin Cance', 'Anorexia',
#        'Postmenopausal Symptoms', 'Insulin Resistance Syndrome',
#        'Peripheral Neuropathy', 'Postherpetic Neuralgia',
#        'Diabetes Type 2', 'Autism', 'Prevention of Osteoporosis',
#        'Hirsutism', 'Schizophrenia', 'Sciatica', 'Narcolepsy',
#        'Herpes Simplex Suppression', 'Bronchitis', 'min)', 'Chronic Pain',
#        'Diarrhea', 'Menstrual Disorders', 'Arrhythmia',
#        'Vaginal Yeast Infection', 'Overactive Bladde',
#        'Bladder Infection', 'Migraine', 'Hot Flashes', 'COPD Maintenance',
#        'lic Acid Deficiency', 'Prostate Cance', 'Acne',
#        'Multiple Sclerosis', 'Ischemic Stroke',
#        'Irritable Bowel Syndrome', 'Back Pain', 'Night Terrors',
#        'Heart Attack', 'Vertig', 'Onychomycosis Toenail',
#        'Macular Degeneration', 'Uterine Fibroids', 'Keratosis',
#        'Migraine Prevention', 'Systemic Lupus Erythematosus',
#        'Urinary Incontinence', 'Agitated State',
#        'Major Depressive Disorde', 'Alcohol Withdrawal',
#        'Chronic Fatigue Syndrome', 'Hyperthyroidism', 'Menorrhagia',
#        'Sjogrens Syndrome', 'Bacterial Infection',
#        'Perimenopausal Symptoms', 'Vitamin D Deficiency', 'Edema',
#        'Restless Legs Syndrome', 'Smoking Cessation', 'Allergic Rhinitis',
#        'Constipation Chronic', 'Diabetic Peripheral Neuropathy',
#        'Oral Thrush', 'Dietary Supplementation', 'Asperger Syndrome',
#        'Bacterial Skin Infection', 'Emergency Contraception', 'Gout',
#        'Barretts Esophagus', 'Tendonitis', 'Burning Mouth Syndrome',
#        'Constipation Acute', 'Angina Pectoris Prophylaxis',
#        'Hypertriglyceridemia', 'GERD',
#        'Upper Respiratory Tract Infection', 'Psoriasis',
#        'Premenstrual Dysphoric Disorde', 'Plaque Psoriasis', 'Tinnitus',
#        'Benign Essential Trem', 'Pneumonia', 'Diarrhea Chronic',
#        'Breast Cancer Adjuvant', 'Prostatitis',
#        'Borderline Personality Disorde', 'Headache', 'Cough',
#        'Supraventricular Tachycardia', 'Basal Cell Carcinoma',
#        'Urinary Tract Stones', 'Stomach Ulce', 'Androgenetic Alopecia',
#        'Shift Work Sleep Disorde', 'Herbal Supplementation',
#        'Diabetes Type 1', 'Gout Acute', 'Nocturnal Leg Cramps',
#        'Nausea/Vomiting', 'Prevention of Bladder infection',
#        'Pseudotumor Cerebri', 'Trigeminal Neuralgia',
#        'Parkinsons Disease', 'Constipation Drug Induced', 'Hepatitis C',
#        'Bulimia', 'Deep Vein Thrombosis', 'Hyperhidrosis',
#        'Erosive Esophagitis', 'Hyperlipoproteinemia',
#        'Mild Cognitive Impairment',
#        'Obstructive Sleep Apnea/Hypopnea Syndrome',
#        'Skin or Soft Tissue Infection', 'Neuropathic Pain',
#        'High Cholesterol Familial Heterozygous', 'Herpes Simplex',
#        'Crohns Disease Maintenance', 'Diabetic Kidney Disease',
#        'Dental Abscess', 'Gas', 'Rosacea', 'Ulcerative Colitis',
#        'moterol)', 'Gouty Arthritis', 'Actinic Keratosis',
#        'Progesterone Insufficiency', 'Asthma', 'Psychosis',
#        'Post Traumatic Stress Disorde', 'Allergic Urticaria',
#        'Acute Coronary Syndrome', 'Crohns Disease', 'Duodenal Ulce',
#        'Non-Hodgkins Lymphoma', 'Hypoestrogenism',
#        'Pulmonary Embolism Recurrent Event', 'Asthma Maintenance',
#        'Thyroid Cance', 'COPD', 'Muscle Pain', 'Human Papilloma Virus',
#        'Cold Sores', 'Diverticulitis', 'Gastroparesis', 'Heart Failure',
#        'Seizures', 'Bowel Preparation', 'Peripheral Arterial Disease',
#        'Seizure Prevention', 'Amenorrhea', 'Mania',
#        'Ischemic Stroke Prophylaxis', 'Menieres Disease', 'Melasma',
#        'Nasal Congestion', 'Autoimmune Hepatitis',
#        'Seasonal Affective Disorde', 'Cluster Headaches',
#        'Intermittent Claudication', 'Expectoration', 'Pancreatic Cance',
#        'Neuralgia', 'Kidney Infections', 'Lyme Disease',
#        'Insomnia Stimulant-Associated', 'Somatoform Pain Disorde',
#        'Herpes Zoste', 'Angina', 'Oophorectomy', 'Performance Anxiety',
#        'Pe', 'Bacterial Vaginitis', 'Hepatitis B', 'Motion Sickness',
#        'Dermatological Disorders', 'Glaucoma Open Angle',
#        'Breakthrough Pain', 'Stress Ulcer Prophylaxis', 'atigue',
#        'Raynauds Syndrome', 'Chlamydia Infection', 'Binge Eating Disorde',
#        'Colorectal Cance', 'Polycythemia Vera', 'Myasthenia Gravis',
#        'Interstitial Cystitis', 'Esophageal Spasm', 'Atopic Dermatitis',
#        'Soft Tissue Sarcoma', 'Breast Cancer Prevention',
#        'Trichomoniasis', 'Keratoconjunctivitis Sicca',
#        'Prevention of Cardiovascular Disease', 'Biliary Cirrhosis',
#        'Cervical Dystonia', 'Glioblastoma Multiforme',
#        'Glioblastoma Multi', 'Endometriosis', 'Anesthesia',
#        'Not Listed / Othe', 'Vulvodynia', 'Diagnosis and Investigation',
#        'Head Lice', 'Iron Deficiency Anemia',
#        'Cough and Nasal Congestion',
#        'Mountain Sickness / Altitude Sickness', 'Crohns Disease Acute',
#        'Skin and Structure Infection', 'Psoriatic Arthritis',
#        'Postpartum Depression', 'Pruritus', 'Schizoaffective Disorde',
#        'Benzodiazepine Withdrawal', 'Gastrointestinal Stromal Tum',
#        'Nightmares', 'Urticaria', 'HIV Infection',
#        'Auditory Processing Disorde', 'Myelodysplastic Syndrome',
#        'Tonsillitis/Pharyngitis', 'Dementia',
#        'Nausea/Vomiting Chemotherapy Induced', 'Period Pain',
#        'Gingivitis', 'Ankylosing Spondylitis', 'AIDS Related Wasting',
#        'Dysuria', 'Hiccups', 'Pulmonary Embolism',
#        'Chronic Lymphocytic Leukemia', 'Atrophic Urethritis',
#        'Hypoactive Sexual Desire Disorde', 'Rhinorrhea', 'Eczema',
#        'Rhinitis', 'Dermatitis',
#        'Hyperlipoproteinemia Type IIa Elevated LDL',
#        'Chronic Pancreatitis', 'Pseudobulbar Affect',
#        'Dietary Fiber Supplementation',
#        'Gastric Ulcer Maintenance Treatment', 'min / sitagliptin)',
#        'Allergic Reactions', 'Bone infection', 'Streptococcal Infection',
#        'Deep Vein Thrombosis First Event',
#        'Reflex Sympathetic Dystrophy Syndrome', 'Hyperprolactinemia',
#        'Hepatic Encephalopathy', 'Seborrheic Dermatitis',
#        'Gastroenteritis', 'Dumping Syndrome', 'Bursitis',
#        'Pulmonary Hypertension', 'Anemia Chemotherapy Induced',
#        'Hepatocellular Carcinoma', 'Inflammatory Bowel Disease',
#        'Asthma acute', 'Helicobacter Pylori Infection',
#        'Esophageal Candidiasis', 'Ovarian Cance', 'Tinea Versicol',
#        'Ventricular Fibrillation', 'High Cholesterol Familial Homozygous',
#        'Herpes Zoster Prophylaxis', 'Dry Skin', 'Lyme Disease Arthritis',
#        'Clostridial Infection', 'Gender Dysphoria', 'Endometrial Cance',
#        'Ovarian Cysts', 'Hypotension', 'Dyspareunia', 'Typhoid Feve',
#        'Hemorrhoids', 'Peptic Ulce', 'B12 Nutritional Deficiency',
#        'ge (amlodipine / valsartan)', 'TSH Suppression',
#        'Ulcerative Colitis Active', 'Pharyngitis',
#        'Pulmonary Embolism First Event', 'Ulcerative Colitis Maintenance',
#        'Tinea Capitis', 'Intraocular Hypertension', 'Tourettes Syndrome',
#        'Undifferentiated Connective Tissue Disease', 'Nasal Polyps',
#        'Influenza', 'Chronic Myelogenous Leukemia',
#        'NSAID-Induced Ulcer Prophylaxis',
#        'Premature Ventricular Depolarizations', 'Xerostomia',
#        'Travelers Diarrhea', 'Dermatomyositis', 'Extrapyramidal Reaction',
#        'Ophthalmic Surgery', 'Onychomycosis Fingernail',
#        'Dry Eye Disease', 'Cutaneous Candidiasis', 'Uterine Bleeding',
#        'Burns External', 'Epilepsy', 'Strep Throat',
#        'Persistent Depressive Disorde', 'Ventricular Tachycardia',
#        'Chronic Spasticity', 'Conjunctivitis Bacterial', 'Hypersomnia',
#        'Pancreatic Exocrine Dysfunction', 'Opiate Adjunct',
#        'Body Dysmorphic Disorde', 'zen Shoulde', 'Tinea Cruris',
#        'Left Ventricular Dysfunction', 'Temporomandibular Joint Disorde',
#        'Vitamin B12 Deficiency', 'Status Epilepticus', 'Allergies',
#        'Hypertensive Emergency', 'Otitis Media', 'Hypokalemia',
#        'ICU Agitation', 'Precocious Puberty',
#        'Neutropenia Associated with Chemotherapy', 'Lipodystrophy',
#        'Trichotillomania', 'Melanoma Metastatic',
#        'Chronic Idiopathic Constipation', 'Lymphocytic Colitis',
#        'Malaria Prevention', 'Conjunctivitis Allergic', 'Atherosclerosis',
#        'Periodic Limb Movement Disorde', 'Primary Hyperaldosteronism',
#        'Indigestion', 'Skin Rash', 'Breast Cancer Palliative',
#        'Postural Orthostatic Tachycardia Syndrome',
#        'Prosthetic Heart Valves Tissue Valves - Thrombosis Prophylaxis',
#        'Peritonitis', 'Multiple Myeloma', 'Cyclic Vomiting Syndrome',
#        'mis', 'Endoscopy or Radiology Premedication',
#        'Mitral Valve Prolapse', 'Oppositional Defiant Disorde',
#        'Atrial Flutte',
#        'Herpes Simplex Mucocutaneous/Immunocompromised Host',
#        'Hypercalcemia of Malignancy', 'Head and Neck Cance',
#        'Menopausal Disorders', 'Varicose Veins', 'Computed Tomography',
#        'Vitamin/Mineral Supplementation and Deficiency', 'Cold Symptoms',
#        'Light Sedation', 'Paroxysmal Supraventricular Tachycardia',
#        'Tinea Corporis', 'Adrenocortical Insufficiency',
#        'Thrombocythemia', 'Paranoid Disorde', 'moterol / mometasone)',
#        'Postoperative Pain', 'Glaucoma', 'Tuberculosis Prophylaxis',
#        'Primary Ovarian Failure', 'Endometrial Hyperplasia',
#        'Coronary Artery Disease', 'Tuberculosis Latent', 'Eye Redness',
#        'Dysautonomia', 'Gastritis/Duodenitis', 'Labor Induction',
#        'Vitamin/Mineral Supplementation during Pregnancy/Lactation',
#        'Malignant Glioma', 'Addisons Disease', 'Light Anesthesia',
#        'Osteolytic Bone Lesions of Multiple Myeloma',
#        'Percutaneous Coronary Intervention', 'Oligospermia',
#        'Dissociative Identity Disorde', 'eve', 'Condylomata Acuminata',
#        'Wegeners Granulomatosis', 'Prevention of Hypokalemia',
#        'Lichen Planus', 'Varicella-Zoste', 'COPD Acute',
#        'Platelet Aggregation Inhibition',
#        'Deep Vein Thrombosis Prophylaxis', 'acial Wrinkles',
#        'Methicillin-Resistant Staphylococcus Aureus Infection',
#        'Aspergillosis Aspergilloma', 'min / saxagliptin)',
#        'Chronic Myofascial Pain', 'Dermatologic Lesion', 'Pagets Disease',
#        'Hereditary Angioedema', 'Tic Disorde', 'Anemia', 'Pemphigus',
#        'Nausea/Vomiting Radiation Induced', 'Severe Mood Dysregulation',
#        'Abortion', 'Salivary Gland Cance', 'Carcinoid Tum', 'Candidemia',
#        'Nephrocalcinosis', 'Postoperative Ocular Inflammation',
#        'Pre-Exposure Prophylaxis', 'Seasonal Allergic Conjunctivitis',
#        'Adult Human Growth Hormone Deficiency',
#        'Anemia Associated with Chronic Renal Failure', 'Tinea Pedis',
#        'Osteolytic Bone Metastases of Solid Tumors',
#        't Pac with Cyclobenzaprine (cyclobenzaprine)', 'Strongyloidiasis',
#        'Lewy Body Dementia', 'Intermittent Explosive Disorde',
#        'Nonalcoholic Fatty Liver Disease', 'Bronchospasm Prophylaxis',
#        'Immunosuppression', 'Opioid Overdose', 'Anemia Sickle Cell',
#        'Myxedema Coma', 'New Daily Persistent Headache',
#        'Ear Wax Impaction', 'Lactose Intolerance',
#        'Human Papillomavirus Prophylaxis',
#        'Organ Transplant Rejection Prophylaxis',
#        'Anal Fissure and Fistula', 'Macular Edema', 'Giardiasis',
#        'Gastrointestinal Decontamination',
#        'Pinworm Infection (Enterobius vermicularis)',
#        'Herpes Simplex Mucocutaneous/Immunocompetent Host',
#        'Hypomagnesemia', 'Uveitis', 'Lennox-Gastaut Syndrome',
#        'Aphthous Ulce', 'Lichen Sclerosus', 'Mucositis',
#        'Noninfectious Colitis', 'Muscle Twitching',
#        'ge HCT (amlodipine / hydrochlorothiazide / valsartan)',
#        'Neutropenia', 'Pneumococcal Disease Prophylaxis',
#        'min / pioglitazone)', 'Behcets Disease',
#        'Eosinophilic Esophagitis', 'Head Injury',
#        'Hyperphosphatemia of Renal Failure', 'Antiphospholipid Syndrome',
#        'NSAID-Induced Gastric Ulce', 'Cerebral Spasticity',
#        'Diarrhea Acute', 'Hidradenitis Suppurativa', 'Premature Lab',
#        'Primary Immunodeficiency Syndrome', 'mist (', 'Enterocolitis',
#        'Thrombocytopenia', 'Nausea/Vomiting of Pregnancy',
#        'Cardiovascular Risk Reduction', 'Costochondritis',
#        'Wolff-Parkinson-White Syndrome', 'Deep Neck Infection',
#        'Nasal Carriage of Staphylococcus aureus',
#        'cal Segmental Glomerulosclerosis', 'Cance',
#        'Infection Prophylaxis', 'Anaplastic Oligodendroglioma',
#        'Cystic Fibrosis', 'Hyperlipoproteinemia Type IV Elevated VLDL',
#        'Brain Tum', 'Short Stature for Age', 'Short Stature',
#        'Hypoparathyroidism', 'Swine Flu', 'Secondary Hyperparathyroidism',
#        'Renal Transplant', 'me', 'Nausea/Vomiting Postoperative',
#        'Cataplexy', 'Periodontitis', 'Schilling Test',
#        'Granuloma Annulare', 'Primary Nocturnal Enuresis',
#        'Pruritus of Partial Biliary Obstruction', 'Sarcoidosis',
#        'Aspiration Pneumonia', 'Dandruff', 'Bleeding Disorde',
#        'Juvenile Idiopathic Arthritis', 'Eye Redness/Itching', 'Neurosis',
#        'Cyclothymic Disorde', 'Pediatric Growth Hormone Deficiency',
#        'Agitation', 'Nephrotic Syndrome', 'Sinus Symptoms',
#        'Rejection Prophylaxis', 'Lyme Disease Neurologic',
#        'Mononucleosis', 'Spondylolisthesis', 'Women (oxybutynin)',
#        'Deep Vein Thrombosis Recurrent Event',
#        'Juvenile Rheumatoid Arthritis', 'Autoimmune Hemolytic Anemia',
#        'tic (mycophenolic acid)', 'Thyroid Suppression Test',
#        'Stills Disease', 'Ascariasis', 'Diaper Rash',
#        'Small Fiber Neuropathy', 'Diabetic Macular Edema', 'Hyperkalemia',
#        'Gallbladder Disease', 'Prevention of Dental Caries',
#        'Post-Cholecystectomy Diarrhea', 'Opioid-Induced Constipation',
#        'Hyperekplexia', 'Coccidioidomycosis',
#        'Esophageal Variceal Hemorrhage Prophylaxis', 'Spondyloarthritis',
#        'Prosthetic Heart Valves Mechanical Valves - Thrombosis Prophylaxis',
#        'Anorexia/Feeding Problems', 'Leukocytoclastic Vasculitis',
#        'Thromboembolic Stroke Prophylaxis', 'Perioral Dermatitis',
#        'Surgical Prophylaxis', 'Corneal Ulce', 'Hairy Cell Leukemia',
#        'Avian Influenza', 'Anesthetic Adjunct',
#        'Candida Urinary Tract Infection', 'Euvolemic Hyponatremia',
#        'Leukemia', 'Mycobacterium avium-intracellulare Treatment',
#        'Meningitis', 'Acetaminophen Overdose', 'Angioedema', 'Labor Pain',
#        'Dermatophytosis', 'Ulcerative Proctitis', 'Women (minoxidil)',
#        'Hypopituitarism', 'Hypercalcemia', 'Subarachnoid Hemorrhage',
#        'Pupillary Dilation', 'Idiopathic Thrombocytopenic Purpura',
#        'Turners Syndrome', 'Diabetes Insipidus',
#        'Squamous Cell Carcinoma', 'Hypoglycemia', 'Tuberculosis Active',
#        'Tardive Dyskinesia', 'Transient Ischemic Attack',
#        'Bronchiectasis', 'Ectopic Pregnancy', 'Lactation Augmentation',
#        'Thyrotoxicosis', 'Influenza Prophylaxis',
#        'Gonadotropin Inhibition', 'Lymphoma', 'Neurosurgery',
#        'Cutaneous T-cell Lymphoma', 'Stomach Cance',
#        'mulation) (phenylephrine)', 'Warts', 'Duodenal Ulcer Prophylaxis',
#        'Conjunctivitis', 'Impetig', 'Acute Nonlymphocytic Leukemia',
#        'Small Bowel Bacterial Overgrowth',
#        'Alpha-1 Proteinase Inhibitor Deficiency',
#        'Acute Lymphoblastic Leukemia', 'Ocular Rosacea',
#        'Pudendal Neuralgia', 'Submental Fullness', 'Reiters Syndrome',
#        'amilial Cold Autoinflammatory Syndrome', 'Dientamoeba fragilis',
#        'Gout Prophylaxis', 'Nocardiosis', 'amilial Mediterranean Feve',
#        'Reversal of Nondepolarizing Muscle Relaxants',
#        'Glaucoma/Intraocular Hypertension', 'Anaplastic Astrocytoma',
#        'actor IX Deficiency', 'Delayed Puberty Male', 'Sleep Paralysis',
#        'Occipital Neuralgia', 'Acute Promyelocytic Leukemia',
#        'min / rosiglitazone)', 'Hemangioma', 'Intraabdominal Infection',
#        'Iritis', 'SIADH', 'Local Anesthesia', 'Linear IgA Disease',
#        'Pain/Feve', 'Systemic Mastocytosis', 'Abdominal Distension',
#        'Pelvic Inflammatory Disease', 'Niacin Deficiency',
#        'Otitis Externa', 'Klinefelter Syndrome', 'Parkinsonism',
#        'Prevention of Perinatal Group B Streptococcal Disease',
#        'Amyotrophic Lateral Sclerosis',
#        'Deep Vein Thrombosis Prophylaxis after Knee Replacement Surgery',
#        'Eyelash Hypotrichosis', 'Cogans Syndrome',
#        'Gonococcal Infection Uncomplicated',
#        'Campylobacter Gastroenteritis', 'von Willebrands Disease',
#        'Bartonellosis', 'Epididymitis Sexually Transmitted',
#        'Pseudogout Prophylaxis', 'Malaria',
#        'Pathological Hypersecretory Conditions',
#        'Cutaneous Larva Migrans', 'Sporotrichosis',
#        'Deep Vein Thrombosis Prophylaxis after Hip Replacement Surgery',
#        'Skin Disinfection Preoperative', 'Anal Itching',
#        'Mixed Connective Tissue Disease', 'Dystonia',
#        'Giant Cell Tumor of Bone', 'Primary Hyperaldosteronism Diagnosis',
#        'Endometrial Hyperplasia Prophylaxis', 'Sore Throat',
#        'Reversal of Opioid Sedation', 'Bacterial Endocarditis Prevention',
#        'ailure to Thrive',
#        'Hyperlipoproteinemia Type III Elevated beta-VLDL   IDL',
#        'Tetanus', 'STD Prophylaxis', 'ibrocystic Breast Disease',
#        'Small Bowel or Pancreatic Fistula',
#        'Herpes Simplex Dendritic Keratitis', 'Neck Pain',
#        'Radionuclide Myocardial Perfusion Study', 'Systemic Candidiasis',
#        'CMV Prophylaxis', 'Aggressive Behavi',
#        'CNS Magnetic Resonance Imaging', 'Anthrax',
#        'Chronic Inflammatory Demyelinating Polyradiculoneuropathy',
#        'Schnitzler Syndrome', 'Diagnostic Bronchograms', 'Croup',
#        'Scleroderma', 'Postoperative Increased Intraocular Pressure',
#        'Pertussis', 'Melanoma',
#        'Hyperparathyroidism Secondary to Renal Impairment',
#        'Ventricular Arrhythmia', 'Oral and Dental Conditions',
#        'Bullous Pemphigoid', 'Wilsons Disease', 'Hypodermoclysis',
#        'Premenstrual Syndrome', 'Histoplasmosis',
#        'Chronic Eosinophilic Leukemia',
#        'Prevention of Atherothrombotic Events', 'Transverse Myelitis',
#        'Gestational Diabetes', 'Wound Cleansing', 'Hypocalcemia',
#        'Pityriasis rubra pilaris', 'llicular Lymphoma',
#        'Pseudomembranous Colitis', 'Dermatitis Herpetiformis',
#        'Dermatitis Herpeti', 'Cerebral Edema', 'Hydrocephalus',
#        'Patent Ductus Arteriosus', 'Porphyria', 'Gastric Cance',
#        'Topical Disinfection', 'Parkinsonian Trem', 'Solid Tumors',
#        'Sepsis', 'Neuritis', 'Nonoccupational Exposure',
#        'Systemic Sclerosis', 'Liver Magnetic Resonance Imaging',
#        'Hyperbilirubinemia', 'Paragonimus westermani Lung Fluke',
#        'Dercums Disease', 'Cluster-Tic Syndrome', 'Joint Infection',
#        'Epicondylitis Tennis Elbow', 'Legionella Pneumonia',
#        'Blepharitis', 'Ehrlichiosis', 'Postpartum Breast Pain',
#        'Amebiasis', 'Pemphigoid', 'Babesiosis', 'ungal Pneumonia',
#        'Dupuytrens contracture', 'Neurotic Depression', 'Hemophilia A',
#        'Ramsay Hunt Syndrome', 'Anti NMDA Receptor Encephalitis',
#        'Neoplastic Diseases', 'Myeloproliferative Disorders',
#        'Infectious Diarrhea', 'Sunburn', 'Body Imaging',
#        'Urinary Retention', 'Meningococcal Meningitis Prophylaxis',
#        'Asystole', 'Gonococcal Infection Disseminated',
#        'Vitamin K Deficiency', 'Hepatic Tum', 'Manscaping Pain',
#        'Mycoplasma Pneumonia', 'Cyclitis', 'Myelofibrosis',
#        'unctional Gastric Disorde', 'Hodgkins Lymphoma',
#        'Secondary Cutaneous Bacterial Infections',
#        'Schistosoma japonicum', 'AV Heart Block', 'Cholera',
#        'Gaucher Disease', 't Care', 'Cerebrovascular Insufficiency',
#        'Q Feve', 'Peripheral T-cell Lymphoma',
#        'Organ Transplant Rejection Reversal', 'Mumps Prophylaxis',
#        'acial Lipoatrophy', 'Microscopic polyangiitis',
#        'Rabies Prophylaxis', 'Hemophilia B',
#        'Hyperuricemia Secondary to Chemotherapy', 'Keratitis',
#        'Strabismus', 'Meningitis Meningococcal', 'Peyronies Disease',
#        'Testicular Cance', 'm Pain Disorde',
#        'Hypokalemic Periodic Paralysis', 'Multiple Endocrine Adenomas',
#        'Upper Limb Spasticity', 'Syringomyelia',
#        'ungal Infection Prophylaxis', 'Hepatitis B Prevention',
#        'Hyperphosphatemia', 'Anaphylaxis', 'Toothache',
#        "Hashimoto's disease", "Alzheimer's Disease",
#        "Barrett's Esophagus", "Sjogren's Syndrome",
#        "Crohn's Disease Maintenance", "Parkinson's Disease",
#        "Meniere's Disease", 'Somat', "Crohn's Disease",
#        "Non-Hodgkin's Lymphoma", "Tourette's Syndrome",
#        "Raynaud's Syndrome", 'Cachexia', "Addison's Disease",
#        "Paget's Disease", "Dercum's Disease", "Behcet's Disease",
#        'Bacteremia', 'Pulmonary Edema', "Still's Disease", 'Ichthyosis',
#        'llicle Stimulation', "Crohn's Disease Acute",
#        'Corneal Refractive Surgery', "Wegener's Granulomatosis",
#        'Gastrointestinal Hemorrhage', "Traveler's Diarrhea", 'Jet Lag',
#        "von Willebrand's Disease", 'Mantle Cell Lymphoma',
#        'Premature Ejaculation', 'Rat-bite Feve', 'Myotonia Congenita',
#        'Lyme Disease Erythema Chronicum Migrans',
#        'Hemorrhoids (pramoxine / zinc oxide)',
#        'Polymyositis/Dermatomyositis', 'Salmonella Gastroenteritis',
#        "Dupuytren's contracture", 'Yellow Fever Prophylaxis',
#        'Acute Otitis Externa', 'Renal Tubular Acidosis',
#        'Aplastic Anemia', 'Pertussis Prophylaxis',
#        'Tympanostomy Tube Placement Surgery', 'Uveitis Posteri',
#        'Occupational Exposure',
#        'Nausea (phosphorated carbohydrate solution)',
#        'Steroid Responsive Inflammatory Conditions'], dtype=object)

# %% [markdown]
# ### Munging Dataset

# %% [markdown]
# #### Segregation Of Required Data

# %%
D = D[D['rating'] >= 7]
D.head()
# Out:
#          drugName                   condition  rating
# 0      Omeprazole  Zollinger-Ellison Syndrome      10
# 1          Mirena               Birth Control      10
# 2  Levonorgestrel               Birth Control      10
# 3          Zoloft                  Depression       9
# 4     Phentermine                 Weight Loss      10

# %% [markdown]
# #### Calculated Field (Rating)

# %%
AvgRating = D.groupby('drugName')['rating'].mean()
AvgRating = pd.DataFrame(AvgRating)
AvgRating.head()
# Out:
#                                         rating
# drugName
# A + D Cracked Skin Relief             10.00000
# A / B Otic                            10.00000
# Abacavir / dolutegravir / lamivudine   9.45614
# Abacavir / lamivudine                 10.00000
# Abacavir / lamivudine / zidovudine     9.00000

# %%
MungedData = pd.merge(AvgRating, D[['drugName', 'condition']], on='drugName')
MungedData = MungedData.drop_duplicates(subset="drugName")
MungedData = MungedData.sort_values(["condition", "rating"], ascending = [True, False])

Rating = MungedData['rating']
Class = []
for i in Rating:
    if i>9:
        Class.append("A")
    elif i>8:
        Class.append("B")
    else:
        Class.append("C")
Class
MungedData['Class'] = Class
MungedData.head()
# Out:
#          drugName     rating condition Class
# 103948  ProCentra  10.000000      ADHD     A
# 29720      Cylert   9.800000      ADHD     A
# 97351    Pemoline   9.800000      ADHD     A
# 32176     Desoxyn   9.666667      ADHD     A
# 133505    Zenzedi   9.571429      ADHD     A

# %%
MungedData.to_csv("/workspaces/Secure-Pharmacist/Python_Model/Datasets/DrugsMungedData.csv", index = False)

# %% [markdown]
# ## Recommendation Model

# %% [markdown]
# ### Basic Models

# %%
# preparing dataset for ML models
Data = pd.read_csv("/workspaces/Secure-Pharmacist/Python_Model/Datasets/DrugsMungedData.csv")
Data["drugName"] = Data["drugName"].astype('category')
Data["condition"] = Data["condition"].astype('category')
Data["Class"] = Data["Class"].astype('category')

ord_enc = OrdinalEncoder()
Data["condition"] = ord_enc.fit_transform(Data[["condition"]])
Data["drugName"] = ord_enc.fit_transform(Data[["drugName"]]) 

Data.head()
# Out:
#    drugName     rating  condition Class
# 0    2497.0  10.000000        0.0     A
# 1     807.0   9.800000        0.0     A
# 2    2349.0   9.800000        0.0     A
# 3     886.0   9.666667        0.0     A
# 4    3333.0   9.571429        0.0     A

# %%
# splitting dataset into train and test data
X = Data.drop(['Class'], axis=1)
Y = Data['Class']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.5, random_state=42)

# %% [markdown]
# #### Naive Bayes Model

# %%
GNB = GaussianNB()
GNB.fit(X_train, Y_train)
Y_predNB = GNB.predict(X_test)

Y_predNB
# Out:
# array(['B', 'A', 'A', ..., 'B', 'A', 'A'], shape=(1699,), dtype='<U1')

# %%
print("Accuracy:",metrics.accuracy_score(Y_test, Y_predNB)) # accuracy testing
print("Confusion Matrix:\n", confusion_matrix(Y_test, Y_predNB))
print('ROC Accuracy Score for Random Forest Model: ', 
      roc_auc_score(Y_test, GNB.predict_proba(X_test), multi_class='ovr'))
# Out:
# Accuracy: 0.9535020600353149
# Confusion Matrix:
#  [[980  70   0]
#  [  0 522   9]
#  [  0   0 118]]
# ROC Accuracy Score for Random Forest Model:  0.9981445146792257

# %% [markdown]
# #### Random Forest Model

# %%
randomForest = RandomForestClassifier(max_depth=2, random_state=0)
randomForest.fit(X_train, Y_train)
Y_predRF = randomForest.predict(X_test)

Y_predRF
# Out:
# array(['B', 'A', 'A', ..., 'B', 'A', 'A'], shape=(1699,), dtype=object)

# %%
print("Accuracy:",metrics.accuracy_score(Y_test, Y_predRF))
print("Confusion Matrix:\n", confusion_matrix(Y_test, Y_predRF))
print('ROC Accuracy Score for Random Forest Model: ', 
      roc_auc_score(Y_test, randomForest.predict_proba(X_test), multi_class='ovr'))
# Out:
# Accuracy: 0.9305473808122425
# Confusion Matrix:
#  [[1050    0    0]
#  [   0  531    0]
#  [   0  118    0]]
# ROC Accuracy Score for Random Forest Model:  1.0

# %% [markdown]
# #### SVC Model

# %%
SVC = make_pipeline(StandardScaler(), SVC(gamma='auto', probability=True))
SVC.fit(X_train, Y_train)
Y_predSVC = SVC.predict(X_test)

Y_predSVC
# Out:
# array(['B', 'A', 'A', ..., 'B', 'A', 'A'], shape=(1699,), dtype=object)

# %%
print("Accuracy:",metrics.accuracy_score(Y_test, Y_predSVC))
print("Confusion Matrix:\n", confusion_matrix(Y_test, Y_predSVC))
print('ROC Accuracy Score for SVC Model: ', 
      roc_auc_score(Y_test, SVC.predict_proba(X_test), multi_class='ovr'))
# Out:
# Accuracy: 0.9552678045909359
# Confusion Matrix:
#  [[978  72   0]
#  [  0 527   4]
#  [  0   0 118]]
# ROC Accuracy Score for SVC Model:  0.9996808410483823

# %% [markdown]
# ### Models Being Ensembled

# %%
estimator = []
estimator.append(('GNB', GNB))
estimator.append(('RF', randomForest))
estimator.append(('SVC', SVC))

# %%
EnsembledVH = VotingClassifier(estimators = estimator, voting ='hard')
EnsembledVH.fit(X_train, Y_train)
Y_predEM = EnsembledVH.predict(X_test)

Y_predEM
# Out:
# array(['B', 'A', 'A', ..., 'B', 'A', 'A'], shape=(1699,), dtype=object)

# %%
print("Accuracy:",metrics.accuracy_score(Y_test, Y_predEM))
print("Confusion Matrix:\n", confusion_matrix(Y_test, Y_predEM))

# One Hot Code Encoding
Y_changedDF = pd.DataFrame()
Y_changedDF['Y_predEM'] = Y_predEM
Y_OHENCdata = pd.get_dummies(Y_changedDF, columns = ['Y_predEM'])

print('ROC Accuracy Score for Ensembled Model: ', 
      roc_auc_score(Y_test, Y_OHENCdata, multi_class='ovr'))
# Out:
# Accuracy: 0.9582107121836374
# Confusion Matrix:
#  [[983  67   0]
#  [  0 527   4]
#  [  0   0 118]]
# ROC Accuracy Score for Ensembled Model:  0.9781274102550953

# %%
Y = EnsembledVH.predict(X)

condition = input("Enter the condition: ").upper()
conditionsUpper = MungedData['condition'].str.upper()
match = conditionsUpper == condition
print("The Drugs for " + condition + " are: ")

print("\nMost Recommended:")
print(MungedData[match & (Y == 'A')]['drugName'])

print("\nSecond Most Recommended:")
print(MungedData[match & (Y == 'B' )]['drugName'])

print("\nLeast Recommended:")
print(MungedData[match & (Y == 'C')]['drugName'])
# Out:
# The Drugs for ADHD are:
#
# Most Recommended:
# 103948            ProCentra
# 29720                Cylert
# 97351              Pemoline
# 32176               Desoxyn
# 133505              Zenzedi
# 80531       Methamphetamine
# 30914              Daytrana
# 85364             Modafinil
# 4751         Adzenys XR-ODT
# 80833              Methylin
# 33209     Dextroamphetamine
# 39213           Dyanavel XR
# 108501           Ritalin LA
# 32889             Dexedrine
# Name: drugName, dtype: object
#
# Second Most Recommended:
# 8499      Amphetamine / dextroamphetamine
# 3938                             Adderall
# 72669                    Lisdexamfetamine
# 8467                          Amphetamine
# 4150                          Adderall XR
# 130689                            Vyvanse
# 33394                          Dextrostat
# 106935                      Quillivant XR
# 62342                              Kapvay
# 27606                            Concerta
# 60913                             Intuniv
# 54225                          Focalin XR
# 79732                         Metadate CD
# 86857                             Mydayis
# 108430                            Ritalin
# 115263                          Strattera
# 56640                          Guanfacine
# 33120                  Dexmethylphenidate
# 11155                         Atomoxetine
# 50782                              Evekeo
# 9516                          Aptensio XR
# 54194                             Focalin
# Name: drugName, dtype: object
#
# Least Recommended:
# 79752    Metadate ER
# Name: drugName, dtype: object
